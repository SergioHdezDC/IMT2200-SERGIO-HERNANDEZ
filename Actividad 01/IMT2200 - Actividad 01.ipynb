# %% [markdown]
# # <img style="float: left; padding-right: 20px; width: 200px" src="https://raw.githubusercontent.com/raxlab/imt2200-data/main/media/logo.jpg">  IMT 2200 - Introducción a Ciencia de Datos
# **Pontificia Universidad Católica de Chile**<br>
# **Instituto de Ingeniería Matemática y Computacional**<br>
# **Semestre 2025-S2**<br>
# **Profesor:** Rodrigo A. Carrasco <br>

# %% [markdown]
# # <h1><center>Actividad 01: Herramientas Computacionales para Ciencia de Datos </center></h1>
#
# ## 1. Objetivos de la Actividad
#
# Esta Actividad tiene como objetivo probar el ambiente de programación de cada estudiante, la instalación de librerías de Python. El segundo objetivo es aprender a usar GitHub, a configurar su repositorio, y entregar la actividad.

# %% [markdown]
# ## 2. Módulos de Python
#
# ### 2.1 Importar módulos
#
# Se recomienda comenzar con la importación de módulos o librerías de funciones para distintos usos, o partes de una libreria
# Para facilitar la referencia a librerías en el resto del código, se acostumbra asignarles un alias. La sintaxis general a usar para importar un módulo es:
#
# ``import NOMBRE_MODULO as ALIAS_MODULO``
# o
# ``from NOMBRE_MODULO import FUNCION``

# %%
#Importación de librerías: importe las siguientes librerías, usando alias comunes: numpy, pandas, geopandas
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 3. Ejercicio: Inspección de Datos del Censo 2017
# El código a continuación permite descargar, leer, hacer algunos cálculos básicos y visualizar los datos de población del censo chileno de 2017 para la región metropolitana.
# En este notebook, ud. sólo debe ejecutar las celdas de código a continuación, hasta generar una figura con la distribución de población total por manzana censal en la RM. Como demostración de la ejecución exitosa del código, debe subir este notebook y la figura final a su repositorio de Github.

# %%
#Leer archivo enun DataFrame
dat=pd.read_csv('Censo2017_Manzanas.csv',delimiter=';')

#Visualizar las primeras lineas
dat.head()
# Out:
#    REGION  PROVINCIA  COMUNA  DC  AREA  ZC_LOC  MZ_ENT  ID_ZONA_LOC  \
# 0       1         11    1101   1     1       1       1         7849
# 1       1         11    1101   1     1       1      10         7849
# 2       1         11    1101   1     1       1      11         7849
# 3       1         11    1101   1     1       1      12         7849
# 4       1         11    1101   1     1       1      13         7849
#
#       ID_MANZENT  PERSONAS  ... MATREC MATIRREC P05_1 P05_2 P05_3 P05_4  \
# 0  1101011001001        15  ...      0        0     0     0     0     0
# 1  1101011001010        70  ...      1        0    15     0     0     0
# 2  1101011001011        36  ...      5        0    15     0     0     0
# 3  1101011001012        65  ...      9        4    24     0     0     0
# 4  1101011001013        39  ...      0        0     9     0     0     0
#
#   REGION_15R PROVINCIA_15R  COMUNA_15R  ID_MANZENT_15R
# 0          1            11        1101   1101011001001
# 1          1            11        1101   1101011001010
# 2          1            11        1101   1101011001011
# 3          1            11        1101   1101011001012
# 4          1            11        1101   1101011001013
#
# [5 rows x 59 columns]

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180499 entries, 0 to 180498
# Data columns (total 59 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   REGION          180499 non-null  int64
#  1   PROVINCIA       180499 non-null  int64
#  2   COMUNA          180499 non-null  int64
#  3   DC              180499 non-null  int64
#  4   AREA            180499 non-null  int64
#  5   ZC_LOC          180499 non-null  int64
#  6   MZ_ENT          180499 non-null  int64
#  7   ID_ZONA_LOC     180499 non-null  int64
#  8   ID_MANZENT      180499 non-null  int64
#  9   PERSONAS        180499 non-null  int64
#  10  HOMBRES         180499 non-null  object
#  11  MUJERES         180499 non-null  object
#  12  EDAD_0A5        180499 non-null  object
#  13  EDAD_6A14       180499 non-null  object
#  14  EDAD_15A64      180499 non-null  object
#  15  EDAD_65YMAS     180499 non-null  object
#  16  INMIGRANTES     180499 non-null  object
#  17  PUEBLO          180499 non-null  object
#  18  VIV_PART        180499 non-null  int64
#  19  VIV_COL         180499 non-null  int64
#  20  VPOMP           180499 non-null  int64
#  21  TOTAL_VIV       180499 non-null  int64
#  22  CANT_HOG        180499 non-null  int64
#  23  P01_1           180499 non-null  int64
#  24  P01_2           180499 non-null  int64
#  25  P01_3           180499 non-null  int64
#  26  P01_4           180499 non-null  int64
#  27  P01_5           180499 non-null  int64
#  28  P01_6           180499 non-null  int64
#  29  P01_7           180499 non-null  int64
#  30  P03A_1          180499 non-null  int64
#  31  P03A_2          180499 non-null  int64
#  32  P03A_3          180499 non-null  int64
#  33  P03A_4          180499 non-null  int64
#  34  P03A_5          180499 non-null  int64
#  35  P03A_6          180499 non-null  int64
#  36  P03B_1          180499 non-null  int64
#  37  P03B_2          180499 non-null  int64
#  38  P03B_3          180499 non-null  int64
#  39  P03B_4          180499 non-null  int64
#  40  P03B_5          180499 non-null  int64
#  41  P03B_6          180499 non-null  int64
#  42  P03B_7          180499 non-null  int64
#  43  P03C_1          180499 non-null  int64
#  44  P03C_2          180499 non-null  int64
#  45  P03C_3          180499 non-null  int64
#  46  P03C_4          180499 non-null  int64
#  47  P03C_5          180499 non-null  int64
#  48  MATACEP         180499 non-null  int64
#  49  MATREC          180499 non-null  int64
#  50  MATIRREC        180499 non-null  int64
#  51  P05_1           180499 non-null  int64
#  52  P05_2           180499 non-null  int64
#  53  P05_3           180499 non-null  int64
#  54  P05_4           180499 non-null  int64
#  55  REGION_15R      180499 non-null  int64
#  56  PROVINCIA_15R   180499 non-null  int64
#  57  COMUNA_15R      180499 non-null  int64
#  58  ID_MANZENT_15R  180499 non-null  int64
# dtypes: int64(51), object(8)
# memory usage: 81.2+ MB

# %% [markdown]
# ### Pregunta: ¿Cuál era la población total de Chile en 2017?
#
# Para responderla podemos hacer un cálculo sencillo y sumar todos los datos de la columna `PERSONAS`:

# %%
#Total de población
total_pop=dat['PERSONAS'].sum()
total_muj=dat['MUJERES'].sum()
print(f'Población total en 2017: {total_pop}')
# Out:
# Población total en 2017: 17574003

# %% [markdown]
# También podemos usar algunas funciones más avanzadas de `pandas`para analizar la distribución de personas por región y edad:

# %%
#Distribución por edad y género
cols=['EDAD_0A5','EDAD_6A14','EDAD_15A64','EDAD_65YMAS']
for col in cols:
    dat[col]=dat[col].replace('*',0).astype(float)
    
pv=pd.pivot_table(dat, index='REGION', values=cols, aggfunc='sum', margins=False)
pv
# Out:
#         EDAD_0A5  EDAD_15A64  EDAD_65YMAS  EDAD_6A14
# REGION
# 1        27089.0    225991.0      22784.0    42860.0
# 2        40763.0    427746.0      40299.0    70497.0
# 3        18862.0    188979.0      23711.0    33304.0
# 4        49130.0    498186.0      77212.0    83390.0
# 5       110371.0   1212273.0     222900.0   176235.0
# 6        58426.0    609723.0      96677.0   100364.0
# 7        62106.0    695161.0     111206.0   108436.0
# 8        98184.0   1049723.0     164977.0   166678.0
# 9        57165.0    629746.0     103612.0    99561.0
# 10       47403.0    555544.0      78907.0    90394.0
# 11        5684.0     67980.0       7017.0    12061.0
# 12        8029.0    112754.0      16636.0    15331.0
# 13      498778.0   4953736.0     731246.0   759246.0
# 14       21771.0    255977.0      41598.0    39097.0
# 15       16207.0    151468.0      22560.0    26333.0
# 16       26815.0    317668.0      56137.0    48137.0

# %% [markdown]
# Y podemos graficar la cantidad por región:

# %%
fig = plt.figure(figsize=(11,3))
ax = fig.add_subplot(111)
ax.set_ylabel('Número de personas')
fig.suptitle('Distribución de población por Edad y Región (Chile, Censo 2017)')
pv.plot(kind='bar', ax =ax);

# %% [markdown]
# ## 4. Creación de un Mapa con información del Censo
#
# A continuación usaremos librerías de geopandas para conectar un mapa de la Región Metropolitana con datos del Censo de 2017.

# %%
#Leer datos censales
manz=gpd.read_file('R13/MANZANA_IND_C17.shp')
com=gpd.read_file('R13/COMUNA_C17.shp')

# %% [markdown]
# Geopandas permite graficar archivos de mapas de múltiples formas. Para más información pueden revisar el siguiente enlace: https://geopandas.org/en/stable/docs/user_guide/mapping.html

# %%
com.plot()
manz.plot()
# Out:
# <Axes: >

# %%
#manz.head(50)
manz[manz["NOM_COMUNA"] == "LO PRADO"].head(50)
#com.head(50)
# Out:
#       REGION                        NOM_REGION PROVINCIA NOM_PROVIN COMUNA  \
# 16463     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16464     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16465     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16466     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16467     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16468     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16469     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16470     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16471     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16472     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16473     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16474     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16475     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16476     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16477     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16478     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16479     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16480     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16481     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16482     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16483     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16484     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16485     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16486     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16487     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16488     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16489     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16490     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16491     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16492     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16493     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16494     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16495     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16496     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16497     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16498     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16499     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16500     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16501     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16502     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16503     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16504     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16505     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16506     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16507     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16508     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16509     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16510     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16511     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
# 16512     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13117
#
#       NOM_COMUNA  DISTRITO  LOC_ZON  ENT_MAN  CATEGORIA NOM_CATEGO  \
# 16463   LO PRADO         1        3        1          1         CD
# 16464   LO PRADO         1        4        7          1         CD
# 16465   LO PRADO         1        4        6          1         CD
# 16466   LO PRADO         1        4        5          1         CD
# 16467   LO PRADO         1        3        2          1         CD
# 16468   LO PRADO         1        4        3          1         CD
# 16469   LO PRADO         1        4        2          1         CD
# 16470   LO PRADO         1        4        1          1         CD
# 16471   LO PRADO         2        1        1          1         CD
# 16472   LO PRADO         6        1       14          1         CD
# 16473   LO PRADO         6        1       13          1         CD
# 16474   LO PRADO         6        1       12          1         CD
# 16475   LO PRADO         6        1        7          1         CD
# 16476   LO PRADO         6        1        6          1         CD
# 16477   LO PRADO         1        3        3          1         CD
# 16478   LO PRADO         2        4        1          1         CD
# 16479   LO PRADO         1        3        4          1         CD
# 16480   LO PRADO         2        4        2          1         CD
# 16481   LO PRADO         6        1        8          1         CD
# 16482   LO PRADO         6        1        5          1         CD
# 16483   LO PRADO         2        1        2          1         CD
# 16484   LO PRADO         2        4        3          1         CD
# 16485   LO PRADO         2        4        4          1         CD
# 16486   LO PRADO         1        3        5          1         CD
# 16487   LO PRADO         1        3        6          1         CD
# 16488   LO PRADO         6        1        9          1         CD
# 16489   LO PRADO         6        1        4          1         CD
# 16490   LO PRADO         1        2        1          1         CD
# 16491   LO PRADO         1        2        2          1         CD
# 16492   LO PRADO         2        4        5          1         CD
# 16493   LO PRADO         1        4       12          1         CD
# 16494   LO PRADO         1        4       13          1         CD
# 16495   LO PRADO         6        1       15          1         CD
# 16496   LO PRADO         6        1       11          1         CD
# 16497   LO PRADO         1        2        3          1         CD
# 16498   LO PRADO         6        1       10          1         CD
# 16499   LO PRADO         6        1        3          1         CD
# 16500   LO PRADO         2        5        4          1         CD
# 16501   LO PRADO         2        1        3          1         CD
# 16502   LO PRADO         2        4        7          1         CD
# 16503   LO PRADO         2        4        8          1         CD
# 16504   LO PRADO         1        3       11          1         CD
# 16505   LO PRADO         1        3       12          1         CD
# 16506   LO PRADO         1        3       10          1         CD
# 16507   LO PRADO         6        1       16          1         CD
# 16508   LO PRADO         6        1       17          1         CD
# 16509   LO PRADO         1        4        8          1         CD
# 16510   LO PRADO         1        4        9          1         CD
# 16511   LO PRADO         1        3        9          1         CD
# 16512   LO PRADO         1        4       10          1         CD
#
#             MANZENT_I  TOTAL_PERS  TOTAL_VIVI  SHAPE_Leng    SHAPE_Area  \
# 16463  13117011003001         196          59    0.004684  1.126228e-06
# 16464  13117011004007         191          59    0.004763  1.166925e-06
# 16465  13117011004006         216          66    0.004440  8.803259e-07
# 16466  13117011004005         144          44    0.004613  1.061649e-06
# 16467  13117011003002         203          57    0.004656  1.143486e-06
# 16468  13117011004003         175          66    0.004978  1.152727e-06
# 16469  13117011004002         138          44    0.003476  7.108197e-07
# 16470  13117011004001         121          35    0.003503  7.420307e-07
# 16471  13117021001001         659         179    0.012874  2.892171e-06
# 16472  13117061001014         121          34    0.003016  5.075521e-07
# 16473  13117061001013         135          36    0.002901  4.322618e-07
# 16474  13117061001012         122          34    0.002888  4.385258e-07
# 16475  13117061001007         157          40    0.003656  5.541295e-07
# 16476  13117061001006         113          39    0.003611  5.505291e-07
# 16477  13117011003003         144          48    0.004007  9.427180e-07
# 16478  13117021004001         673         191    0.004939  1.502560e-06
# 16479  13117011003004         133          38    0.003428  7.195535e-07
# 16480  13117021004002          47          17    0.002727  4.583850e-07
# 16481  13117061001008         144          34    0.003640  5.165269e-07
# 16482  13117061001005         117          37    0.003599  5.131974e-07
# 16483  13117021001002          59          16    0.003805  5.498065e-07
# 16484  13117021004003          41          14    0.002330  3.380616e-07
# 16485  13117021004004          94          28    0.011107  4.961154e-06
# 16486  13117011003005          99          36    0.002979  5.483508e-07
# 16487  13117011003006         120          40    0.002978  5.582131e-07
# 16488  13117061001009         135          35    0.003623  5.071728e-07
# 16489  13117061001004         126          32    0.003585  5.009938e-07
# 16490  13117011002001         157          42    0.002949  5.445705e-07
# 16491  13117011002002          90          24    0.002855  5.143646e-07
# 16492  13117021004005          55          14    0.002326  3.033346e-07
# 16493  13117011004012         158          46    0.003720  8.330560e-07
# 16494  13117011004013         257          84    0.005344  1.403740e-06
# 16495  13117061001015          81          19    0.002707  4.013479e-07
# 16496  13117061001011           0           1    0.001658  1.762222e-07
# 16497  13117011002003         106          26    0.003204  5.833459e-07
# 16498  13117061001010         154          43    0.003682  5.857630e-07
# 16499  13117061001003         101          30    0.003658  5.745862e-07
# 16500  13117021005004        1286         416    0.007803  2.358608e-06
# 16501  13117021001003          84          25    0.001935  2.369727e-07
# 16502  13117021004007          77          24    0.003299  5.211248e-07
# 16503  13117021004008          40          14    0.002377  3.302939e-07
# 16504  13117011003011         129          38    0.003499  7.195611e-07
# 16505  13117011003012          94          35    0.003489  7.178780e-07
# 16506  13117011003010         164          39    0.003341  6.358744e-07
# 16507  13117061001016          68          22    0.002605  3.315976e-07
# 16508  13117061001017           0           1    0.001560  1.508536e-07
# 16509  13117011004008         111          42    0.003733  8.583123e-07
# 16510  13117011004009          80          27    0.003072  4.861790e-07
# 16511  13117011003009         135          46    0.003438  6.789031e-07
# 16512  13117011004010         126          46    0.003400  6.809786e-07
#
#                                                 geometry
# 16463  POLYGON ((-70.72956 -33.43804, -70.73008 -33.4...
# 16464  POLYGON ((-70.73024 -33.43805, -70.73083 -33.4...
# 16465  POLYGON ((-70.73098 -33.43807, -70.73133 -33.4...
# 16466  POLYGON ((-70.73148 -33.43808, -70.73199 -33.4...
# 16467  POLYGON ((-70.72888 -33.43803, -70.72941 -33.4...
# 16468  POLYGON ((-70.73307 -33.43842, -70.73308 -33.4...
# 16469  POLYGON ((-70.73334 -33.43754, -70.734 -33.437...
# 16470  POLYGON ((-70.73402 -33.43658, -70.73405 -33.4...
# 16471  POLYGON ((-70.71969 -33.43697, -70.71964 -33.4...
# 16472  POLYGON ((-70.73483 -33.43752, -70.73484 -33.4...
# 16473  POLYGON ((-70.73529 -33.43659, -70.73529 -33.4...
# 16474  POLYGON ((-70.73573 -33.43648, -70.73575 -33.4...
# 16475  POLYGON ((-70.73622 -33.43652, -70.73622 -33.4...
# 16476  POLYGON ((-70.73776 -33.43656, -70.73776 -33.4...
# 16477  POLYGON ((-70.72822 -33.4381, -70.72823 -33.43...
# 16478  POLYGON ((-70.719 -33.43846, -70.71937 -33.438...
# 16479  POLYGON ((-70.72756 -33.43816, -70.72757 -33.4...
# 16480  POLYGON ((-70.71802 -33.43804, -70.71803 -33.4...
# 16481  POLYGON ((-70.73622 -33.43723, -70.73769 -33.4...
# 16482  POLYGON ((-70.73776 -33.43688, -70.73776 -33.4...
# 16483  POLYGON ((-70.72106 -33.43722, -70.72115 -33.4...
# 16484  POLYGON ((-70.71718 -33.43773, -70.71719 -33.4...
# 16485  POLYGON ((-70.71422 -33.43767, -70.71288 -33.4...
# 16486  POLYGON ((-70.7269 -33.43826, -70.72691 -33.43...
# 16487  POLYGON ((-70.72625 -33.43835, -70.72626 -33.4...
# 16488  POLYGON ((-70.73622 -33.43749, -70.73623 -33.4...
# 16489  POLYGON ((-70.73776 -33.4376, -70.73921 -33.43...
# 16490  POLYGON ((-70.72557 -33.43845, -70.72559 -33.4...
# 16491  POLYGON ((-70.72492 -33.43854, -70.72493 -33.4...
# 16492  POLYGON ((-70.71639 -33.43825, -70.71639 -33.4...
# 16493  POLYGON ((-70.73373 -33.43891, -70.73374 -33.4...
# 16494  POLYGON ((-70.73425 -33.43958, -70.73464 -33.4...
# 16495  POLYGON ((-70.73477 -33.4378, -70.73477 -33.43...
# 16496  POLYGON ((-70.73606 -33.43756, -70.73596 -33.4...
# 16497  POLYGON ((-70.72386 -33.43869, -70.72387 -33.4...
# 16498  POLYGON ((-70.73626 -33.43803, -70.73627 -33.4...
# 16499  POLYGON ((-70.73782 -33.43803, -70.73785 -33.4...
# 16500  POLYGON ((-70.70712 -33.43851, -70.7072 -33.43...
# 16501  POLYGON ((-70.72012 -33.43854, -70.72045 -33.4...
# 16502  POLYGON ((-70.71734 -33.43858, -70.71737 -33.4...
# 16503  POLYGON ((-70.71647 -33.43869, -70.71648 -33.4...
# 16504  POLYGON ((-70.72893 -33.43925, -70.72936 -33.4...
# 16505  POLYGON ((-70.72954 -33.43926, -70.73005 -33.4...
# 16506  POLYGON ((-70.72837 -33.4393, -70.72839 -33.43...
# 16507  POLYGON ((-70.73477 -33.43837, -70.73573 -33.4...
# 16508  POLYGON ((-70.73576 -33.43837, -70.73619 -33.4...
# 16509  POLYGON ((-70.73043 -33.43927, -70.73082 -33.4...
# 16510  POLYGON ((-70.73102 -33.43927, -70.73126 -33.4...
# 16511  POLYGON ((-70.72781 -33.43941, -70.72784 -33.4...
# 16512  POLYGON ((-70.73184 -33.43935, -70.73185 -33.4...

# %% [markdown]
# El siguiente código conecta el mapa de la Región Metropolitana con la población por manzana del Censo 2017. Edite el código para que la figura tenga su nombre en el Titulo

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.colors as colors

#Crear figura y ejes
fig=plt.figure(figsize=(13,13))
ax=fig.add_subplot(111)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)

# cantidad de personas por manzana
manz = manz[manz["NOM_COMUNA"] == "LO PRADO"]
Z=manz['TOTAL_PERS']
manz.plot(ax=ax, column='TOTAL_PERS', cmap='Greens', legend=True, vmin=0, vmax=800)

com_projected = com.to_crs(epsg=3857)
com_projected.boundary.plot(ax=ax, lw=0.2, color='k')
c = [-33.445, -70.72]
range_x = 0.03
range_y = 0.015
xlim= [c[1] - range_x, c[1] + range_x]
ylim= [c[0] - range_y, c[0] + range_y]
#xlim=[-70.8,-70.5]
#ylim=[-33.5,-33.4]
for x, y, label in zip(com_projected.geometry.centroid.x, com_projected.geometry.centroid.y, com_projected.NOM_COMUNA):
    if xlim[0]<x<xlim[1] and ylim[0]<y<ylim[1]:
        ax.text(x, y, label, fontsize = 10)
        
ax.set_xlim(xlim)
ax.set_ylim(ylim);

## Reemplace 'XXX' por su apellido
ax.set_title('RM - Población total por manzana Comuna de Lo Prado, Santiago - Censo 2017 - Ejecutado por Hernandez',fontsize=10)

## Reemplace 'XXX' por su apellido en el nombre del archivo de salida 
fig.savefig('PoblacionRM_C2017_Hernandez.jpg')

#Crear figura y ejes
fig=plt.figure(figsize=(13,13))
ax=fig.add_subplot(111)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)

# cantidad de viviendas por manzana
manz = manz[manz["NOM_COMUNA"] == "LO PRADO"]
Z=manz['TOTAL_VIVI']
manz.plot(ax=ax, column='TOTAL_VIVI', cmap='Blues', legend=True, vmin=0, vmax=200)

com_projected = com.to_crs(epsg=3857)
com_projected.boundary.plot(ax=ax, lw=0.2, color='k')
c = [-33.445, -70.72]
range_x = 0.03
range_y = 0.015
xlim= [c[1] - range_x, c[1] + range_x]
ylim= [c[0] - range_y, c[0] + range_y]
#xlim=[-70.8,-70.5]
#ylim=[-33.5,-33.4]
for x, y, label in zip(com_projected.geometry.centroid.x, com_projected.geometry.centroid.y, com_projected.NOM_COMUNA):
    if xlim[0]<x<xlim[1] and ylim[0]<y<ylim[1]:
        ax.text(x, y, label, fontsize = 10)
        
ax.set_xlim(xlim)
ax.set_ylim(ylim);

## Reemplace 'XXX' por su apellido
ax.set_title('RM - Viviendas por manzana Comuna de Lo Prado, Santiago - Censo 2017 - Ejecutado por Hernandez',fontsize=10)

## Reemplace 'XXX' por su apellido en el nombre del archivo de salida 
fig.savefig('PoblacionRM_C2017_viviendas_Hernandez.jpg')

# %% [markdown]
# ## 5. Cierre de la Actividad 01: Repositorio presonal
#
# Para terminar la Actividad 01, deben hacer los siguientes pasos:
# - Crear un repositorio en su cuenta personal con el nombre ``IMT2200-<NOMBRE>-<APELLIDO>`` y clonar en su computador.
# - Crear una carpeta adentro llamada "Actividad 01" y copiar adentro el contenido de la carpeta "Actividad 01" del repositorio del curso.
# - Actualizar el repositorio agregando el Notebook de Jupyter y la imagen con el Mapa con su nombre.
# - Editar el archivo ``README.md`` para describir su repositorio.
# - Entregar en el módulo ``Actividad 1`` en Canvas la URL de su repositorio para corrección.
