# %% [markdown]
# # <img style="float: left; padding-right: 20px; width: 200px" src="https://raw.githubusercontent.com/raxlab/imt2200-data/main/media/logo.jpg">  IMT 2200 - Introducción a Ciencia de Datos
# **Pontificia Universidad Católica de Chile**<br>
# **Instituto de Ingeniería Matemática y Computacional**<br>
# **Semestre 2025-S2**<br>
# **Profesor:** Rodrigo A. Carrasco <br>

# %% [markdown]
# # <h1><center>Actividad 01: Herramientas Computacionales para Ciencia de Datos </center></h1>
#
# ## 1. Objetivos de la Actividad
#
# Esta Actividad tiene como objetivo probar el ambiente de programación de cada estudiante, la instalación de librerías de Python. El segundo objetivo es aprender a usar GitHub, a configurar su repositorio, y entregar la actividad.

# %% [markdown]
# ## 2. Módulos de Python
#
# ### 2.1 Importar módulos
#
# Se recomienda comenzar con la importación de módulos o librerías de funciones para distintos usos, o partes de una libreria
# Para facilitar la referencia a librerías en el resto del código, se acostumbra asignarles un alias. La sintaxis general a usar para importar un módulo es:
#
# ``import NOMBRE_MODULO as ALIAS_MODULO``
# o
# ``from NOMBRE_MODULO import FUNCION``

# %%
#Importación de librerías: importe las siguientes librerías, usando alias comunes: numpy, pandas, geopandas
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 3. Ejercicio: Inspección de Datos del Censo 2017
# El código a continuación permite descargar, leer, hacer algunos cálculos básicos y visualizar los datos de población del censo chileno de 2017 para la región metropolitana.
# En este notebook, ud. sólo debe ejecutar las celdas de código a continuación, hasta generar una figura con la distribución de población total por manzana censal en la RM. Como demostración de la ejecución exitosa del código, debe subir este notebook y la figura final a su repositorio de Github.

# %%
#Leer archivo enun DataFrame
dat=pd.read_csv('Censo2017_Manzanas.csv',delimiter=';')

#Visualizar las primeras lineas
dat.head()
# Out:
#    REGION  PROVINCIA  COMUNA  DC  AREA  ZC_LOC  MZ_ENT  ID_ZONA_LOC  \
# 0       1         11    1101   1     1       1       1         7849
# 1       1         11    1101   1     1       1      10         7849
# 2       1         11    1101   1     1       1      11         7849
# 3       1         11    1101   1     1       1      12         7849
# 4       1         11    1101   1     1       1      13         7849
#
#       ID_MANZENT  PERSONAS  ... MATREC MATIRREC P05_1 P05_2 P05_3 P05_4  \
# 0  1101011001001        15  ...      0        0     0     0     0     0
# 1  1101011001010        70  ...      1        0    15     0     0     0
# 2  1101011001011        36  ...      5        0    15     0     0     0
# 3  1101011001012        65  ...      9        4    24     0     0     0
# 4  1101011001013        39  ...      0        0     9     0     0     0
#
#   REGION_15R PROVINCIA_15R  COMUNA_15R  ID_MANZENT_15R
# 0          1            11        1101   1101011001001
# 1          1            11        1101   1101011001010
# 2          1            11        1101   1101011001011
# 3          1            11        1101   1101011001012
# 4          1            11        1101   1101011001013
#
# [5 rows x 59 columns]

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180499 entries, 0 to 180498
# Data columns (total 59 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   REGION          180499 non-null  int64
#  1   PROVINCIA       180499 non-null  int64
#  2   COMUNA          180499 non-null  int64
#  3   DC              180499 non-null  int64
#  4   AREA            180499 non-null  int64
#  5   ZC_LOC          180499 non-null  int64
#  6   MZ_ENT          180499 non-null  int64
#  7   ID_ZONA_LOC     180499 non-null  int64
#  8   ID_MANZENT      180499 non-null  int64
#  9   PERSONAS        180499 non-null  int64
#  10  HOMBRES         180499 non-null  object
#  11  MUJERES         180499 non-null  object
#  12  EDAD_0A5        180499 non-null  object
#  13  EDAD_6A14       180499 non-null  object
#  14  EDAD_15A64      180499 non-null  object
#  15  EDAD_65YMAS     180499 non-null  object
#  16  INMIGRANTES     180499 non-null  object
#  17  PUEBLO          180499 non-null  object
#  18  VIV_PART        180499 non-null  int64
#  19  VIV_COL         180499 non-null  int64
#  20  VPOMP           180499 non-null  int64
#  21  TOTAL_VIV       180499 non-null  int64
#  22  CANT_HOG        180499 non-null  int64
#  23  P01_1           180499 non-null  int64
#  24  P01_2           180499 non-null  int64
#  25  P01_3           180499 non-null  int64
#  26  P01_4           180499 non-null  int64
#  27  P01_5           180499 non-null  int64
#  28  P01_6           180499 non-null  int64
#  29  P01_7           180499 non-null  int64
#  30  P03A_1          180499 non-null  int64
#  31  P03A_2          180499 non-null  int64
#  32  P03A_3          180499 non-null  int64
#  33  P03A_4          180499 non-null  int64
#  34  P03A_5          180499 non-null  int64
#  35  P03A_6          180499 non-null  int64
#  36  P03B_1          180499 non-null  int64
#  37  P03B_2          180499 non-null  int64
#  38  P03B_3          180499 non-null  int64
#  39  P03B_4          180499 non-null  int64
#  40  P03B_5          180499 non-null  int64
#  41  P03B_6          180499 non-null  int64
#  42  P03B_7          180499 non-null  int64
#  43  P03C_1          180499 non-null  int64
#  44  P03C_2          180499 non-null  int64
#  45  P03C_3          180499 non-null  int64
#  46  P03C_4          180499 non-null  int64
#  47  P03C_5          180499 non-null  int64
#  48  MATACEP         180499 non-null  int64
#  49  MATREC          180499 non-null  int64
#  50  MATIRREC        180499 non-null  int64
#  51  P05_1           180499 non-null  int64
#  52  P05_2           180499 non-null  int64
#  53  P05_3           180499 non-null  int64
#  54  P05_4           180499 non-null  int64
#  55  REGION_15R      180499 non-null  int64
#  56  PROVINCIA_15R   180499 non-null  int64
#  57  COMUNA_15R      180499 non-null  int64
#  58  ID_MANZENT_15R  180499 non-null  int64
# dtypes: int64(51), object(8)
# memory usage: 81.2+ MB

# %% [markdown]
# ### Pregunta: ¿Cuál era la población total de Chile en 2017?
#
# Para responderla podemos hacer un cálculo sencillo y sumar todos los datos de la columna `PERSONAS`:

# %%
#Total de población
total_pop=dat['PERSONAS'].sum()
total_muj=dat['MUJERES'].sum()
print(f'Población total en 2017: {total_pop}')
# Out:
# Población total en 2017: 17574003

# %% [markdown]
# También podemos usar algunas funciones más avanzadas de `pandas`para analizar la distribución de personas por región y edad:

# %%
#Distribución por edad y género
cols=['EDAD_0A5','EDAD_6A14','EDAD_15A64','EDAD_65YMAS']
for col in cols:
    dat[col]=dat[col].replace('*',0).astype(float)
    
pv=pd.pivot_table(dat, index='REGION', values=cols, aggfunc='sum', margins=False)
pv
# Out:
#         EDAD_0A5  EDAD_15A64  EDAD_65YMAS  EDAD_6A14
# REGION
# 1        27089.0    225991.0      22784.0    42860.0
# 2        40763.0    427746.0      40299.0    70497.0
# 3        18862.0    188979.0      23711.0    33304.0
# 4        49130.0    498186.0      77212.0    83390.0
# 5       110371.0   1212273.0     222900.0   176235.0
# 6        58426.0    609723.0      96677.0   100364.0
# 7        62106.0    695161.0     111206.0   108436.0
# 8        98184.0   1049723.0     164977.0   166678.0
# 9        57165.0    629746.0     103612.0    99561.0
# 10       47403.0    555544.0      78907.0    90394.0
# 11        5684.0     67980.0       7017.0    12061.0
# 12        8029.0    112754.0      16636.0    15331.0
# 13      498778.0   4953736.0     731246.0   759246.0
# 14       21771.0    255977.0      41598.0    39097.0
# 15       16207.0    151468.0      22560.0    26333.0
# 16       26815.0    317668.0      56137.0    48137.0

# %% [markdown]
# Y podemos graficar la cantidad por región:

# %%
fig = plt.figure(figsize=(11,3))
ax = fig.add_subplot(111)
ax.set_ylabel('Número de personas')
fig.suptitle('Distribución de población por Edad y Región (Chile, Censo 2017)')
pv.plot(kind='bar', ax =ax);

# %% [markdown]
# ## 4. Creación de un Mapa con información del Censo
#
# A continuación usaremos librerías de geopandas para conectar un mapa de la Región Metropolitana con datos del Censo de 2017.

# %%
#Leer datos censales
manz=gpd.read_file('R13/MANZANA_IND_C17.shp')
com=gpd.read_file('R13/COMUNA_C17.shp')

# %% [markdown]
# Geopandas permite graficar archivos de mapas de múltiples formas. Para más información pueden revisar el siguiente enlace: https://geopandas.org/en/stable/docs/user_guide/mapping.html

# %%
com.plot()
manz.plot()
# Out:
# <Axes: >

# %%
manz.head(50)
#com.head(50)
# Out:
#    REGION                        NOM_REGION PROVINCIA NOM_PROVIN COMUNA  \
# 0      13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 1      13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 2      13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 3      13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 4      13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 5      13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 6      13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 7      13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 8      13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 9      13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 10     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 11     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 12     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 13     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 14     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 15     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 16     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 17     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 18     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 19     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 20     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 21     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 22     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 23     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 24     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 25     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 26     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 27     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 28     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 29     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 30     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 31     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 32     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 33     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 34     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 35     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 36     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 37     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 38     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 39     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 40     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 41     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 42     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 43     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 44     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 45     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 46     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 47     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 48     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
# 49     13  REGIÓN METROPOLITANA DE SANTIAGO       131   SANTIAGO  13101
#
#    NOM_COMUNA  DISTRITO  LOC_ZON  ENT_MAN  CATEGORIA NOM_CATEGO  \
# 0    SANTIAGO         7        1        2          1         CD
# 1    SANTIAGO         8        1        2          1         CD
# 2    SANTIAGO         7        1        3          1         CD
# 3    SANTIAGO         7        1        4          1         CD
# 4    SANTIAGO         7        1        8          1         CD
# 5    SANTIAGO         7        1        9          1         CD
# 6    SANTIAGO         8        1        3          1         CD
# 7    SANTIAGO         8        3        2          1         CD
# 8    SANTIAGO         8        3        3          1         CD
# 9    SANTIAGO         8        3        5          1         CD
# 10   SANTIAGO         8        3        8          1         CD
# 11   SANTIAGO         7        1        7          1         CD
# 12   SANTIAGO         8        3        6          1         CD
# 13   SANTIAGO         8        3        7          1         CD
# 14   SANTIAGO         8        4        1          1         CD
# 15   SANTIAGO         7        1        5          1         CD
# 16   SANTIAGO         8        1        6          1         CD
# 17   SANTIAGO         9        1       10          1         CD
# 18   SANTIAGO         8        1        4          1         CD
# 19   SANTIAGO         8        1        5          1         CD
# 20   SANTIAGO         7        1       10          1         CD
# 21   SANTIAGO         8        4        2          1         CD
# 22   SANTIAGO         9        1        9          1         CD
# 23   SANTIAGO         8        3        9          1         CD
# 24   SANTIAGO         8        3       12          1         CD
# 25   SANTIAGO         9        1        7          1         CD
# 26   SANTIAGO         7        1        6          1         CD
# 27   SANTIAGO         9        1       11          1         CD
# 28   SANTIAGO         9        1        6          1         CD
# 29   SANTIAGO         8        1        7          1         CD
# 30   SANTIAGO         8        3       10          1         CD
# 31   SANTIAGO         7        1       11          1         CD
# 32   SANTIAGO         9        1       12          1         CD
# 33   SANTIAGO         7        1       12          1         CD
# 34   SANTIAGO         7        1       13          1         CD
# 35   SANTIAGO         8        3       11          1         CD
# 36   SANTIAGO         9        1        8          1         CD
# 37   SANTIAGO         9        1       13          1         CD
# 38   SANTIAGO         9        1       20          1         CD
# 39   SANTIAGO         9        1       19          1         CD
# 40   SANTIAGO         9        1       14          1         CD
# 41   SANTIAGO         3        1        3          1         CD
# 42   SANTIAGO         9        1       18          1         CD
# 43   SANTIAGO         9        1       15          1         CD
# 44   SANTIAGO         8        4        3          1         CD
# 45   SANTIAGO         9        1       21          1         CD
# 46   SANTIAGO         9        1       17          1         CD
# 47   SANTIAGO         7        1       16          1         CD
# 48   SANTIAGO         9        1       16          1         CD
# 49   SANTIAGO         8        3       13          1         CD
#
#          MANZENT_I  TOTAL_PERS  TOTAL_VIVI  SHAPE_Leng    SHAPE_Area  \
# 0   13101071001002         764         287    0.005560  1.354544e-06
# 1   13101081001002        1307         509    0.006557  2.630421e-06
# 2   13101071001003          64          17    0.003859  5.979189e-07
# 3   13101071001004          52          21    0.004683  1.265246e-06
# 4   13101071001008          67          14    0.003491  7.452444e-07
# 5   13101071001009         143          47    0.005930  1.177970e-06
# 6   13101081001003          18           9    0.004470  1.241989e-06
# 7   13101081003002          26          13    0.001761  1.386399e-07
# 8   13101081003003          73          16    0.002161  1.716355e-07
# 9   13101081003005          14           5    0.001298  1.089692e-07
# 10  13101081003008        1059         484    0.002981  5.585401e-07
# 11  13101071001007         159          54    0.005256  1.202109e-06
# 12  13101081003006          37          17    0.001847  1.350204e-07
# 13  13101081003007         188          69    0.005841  5.276989e-07
# 14  13101081004001         662         259    0.006668  1.997679e-06
# 15  13101071001005         109          42    0.004194  6.080899e-07
# 16  13101081001006          84          32    0.003614  8.220552e-07
# 17  13101091001010         515         229    0.003871  7.323818e-07
# 18  13101081001004          23           9    0.002948  5.423425e-07
# 19  13101081001005        2005         689    0.013414  3.827605e-06
# 20  13101071001010        1331         446    0.018512  3.764976e-06
# 21  13101081004002         603         407    0.010469  2.969983e-06
# 22  13101091001009          88         223    0.002721  4.544696e-07
# 23  13101081003009          76          22    0.002689  4.423455e-07
# 24  13101081003012        1037         402    0.007859  2.085765e-06
# 25  13101091001007           7         159    0.002287  3.298358e-07
# 26  13101071001006          32          16    0.002787  4.509042e-07
# 27  13101091001011          99          32    0.003357  4.300925e-07
# 28  13101091001006         569         278    0.003714  7.477078e-07
# 29  13101081001007         259         119    0.004633  1.237206e-06
# 30  13101081003010          76          21    0.002055  1.593004e-07
# 31  13101071001011         554         169    0.009202  1.211757e-06
# 32  13101091001012         174          52    0.003345  3.989976e-07
# 33  13101071001012         187          61    0.005262  1.212552e-06
# 34  13101071001013          42         280    0.004274  1.157488e-06
# 35  13101081003011         105          28    0.002113  1.890426e-07
# 36  13101091001008         152          53    0.002961  3.838254e-07
# 37  13101091001013         199          71    0.003376  4.370632e-07
# 38  13101091001020          85          32    0.004744  7.992347e-07
# 39  13101091001019         139          42    0.002940  3.611202e-07
# 40  13101091001014         143          47    0.003360  4.309641e-07
# 41  13101031001003          52          25    0.002860  4.927295e-07
# 42  13101091001018         150          39    0.002920  3.416295e-07
# 43  13101091001015         205          50    0.003351  3.997179e-07
# 44  13101081004003         611         240    0.005151  1.463071e-06
# 45  13101091001021         119          34    0.003116  4.077807e-07
# 46  13101091001017          62          28    0.002957  3.952408e-07
# 47  13101071001016        1086         464    0.004104  1.082384e-06
# 48  13101091001016         143          42    0.003433  4.719236e-07
# 49  13101081003013          59          18    0.002420  1.895756e-07
#
#                                              geometry
# 0   POLYGON ((-70.67695 -33.42691, -70.67685 -33.4...
# 1   POLYGON ((-70.67362 -33.42898, -70.67517 -33.4...
# 2   POLYGON ((-70.67812 -33.42803, -70.67813 -33.4...
# 3   POLYGON ((-70.68043 -33.42897, -70.68046 -33.4...
# 4   POLYGON ((-70.67805 -33.42921, -70.67858 -33.4...
# 5   POLYGON ((-70.67678 -33.42842, -70.67673 -33.4...
# 6   POLYGON ((-70.67602 -33.42913, -70.67658 -33.4...
# 7   POLYGON ((-70.67141 -33.42906, -70.67167 -33.4...
# 8   POLYGON ((-70.67079 -33.42871, -70.67088 -33.4...
# 9   POLYGON ((-70.67045 -33.42905, -70.6708 -33.42...
# 10  POLYGON ((-70.66956 -33.42968, -70.67027 -33.4...
# 11  POLYGON ((-70.67874 -33.4292, -70.67866 -33.43...
# 12  POLYGON ((-70.6708 -33.42908, -70.6708 -33.429...
# 13  POLYGON ((-70.67092 -33.42906, -70.67091 -33.4...
# 14  POLYGON ((-70.67401 -33.43166, -70.67403 -33.4...
# 15  POLYGON ((-70.67979 -33.42922, -70.67975 -33.4...
# 16  POLYGON ((-70.67431 -33.43011, -70.67512 -33.4...
# 17  POLYGON ((-70.66797 -33.42993, -70.66926 -33.4...
# 18  POLYGON ((-70.67522 -33.43, -70.67585 -33.4300...
# 19  POLYGON ((-70.67585 -33.43007, -70.67585 -33.4...
# 20  POLYGON ((-70.67672 -33.42943, -70.67672 -33.4...
# 21  POLYGON ((-70.67164 -33.43017, -70.67149 -33.4...
# 22  POLYGON ((-70.66748 -33.43057, -70.66776 -33.4...
# 23  POLYGON ((-70.66948 -33.43025, -70.67031 -33.4...
# 24  POLYGON ((-70.67044 -33.42976, -70.67043 -33.4...
# 25  POLYGON ((-70.66686 -33.43056, -70.66709 -33.4...
# 26  POLYGON ((-70.68057 -33.4303, -70.68059 -33.43...
# 27  POLYGON ((-70.6679 -33.4303, -70.66928 -33.430...
# 28  POLYGON ((-70.66527 -33.4309, -70.66645 -33.43...
# 29  POLYGON ((-70.67423 -33.43167, -70.67492 -33.4...
# 30  POLYGON ((-70.66946 -33.43047, -70.67029 -33.4...
# 31  POLYGON ((-70.67755 -33.43019, -70.67744 -33.4...
# 32  POLYGON ((-70.66786 -33.43062, -70.66925 -33.4...
# 33  POLYGON ((-70.67862 -33.43048, -70.67853 -33.4...
# 34  POLYGON ((-70.67964 -33.43158, -70.68044 -33.4...
# 35  POLYGON ((-70.67022 -33.4308, -70.67024 -33.43...
# 36  POLYGON ((-70.66722 -33.43094, -70.66772 -33.4...
# 37  POLYGON ((-70.66805 -33.43096, -70.66916 -33.4...
# 38  POLYGON ((-70.66522 -33.43106, -70.66519 -33.4...
# 39  POLYGON ((-70.66714 -33.43132, -70.66771 -33.4...
# 40  POLYGON ((-70.66779 -33.43134, -70.66917 -33.4...
# 41  POLYGON ((-70.65947 -33.43198, -70.66039 -33.4...
# 42  POLYGON ((-70.6671 -33.43164, -70.66768 -33.43...
# 43  POLYGON ((-70.66776 -33.43165, -70.66915 -33.4...
# 44  POLYGON ((-70.67149 -33.43137, -70.67139 -33.4...
# 45  POLYGON ((-70.66521 -33.43198, -70.66637 -33.4...
# 46  POLYGON ((-70.66758 -33.43203, -70.6676 -33.43...
# 47  POLYGON ((-70.67826 -33.43273, -70.67829 -33.4...
# 48  POLYGON ((-70.66907 -33.43205, -70.66908 -33.4...
# 49  POLYGON ((-70.67032 -33.43166, -70.6703 -33.43...

# %% [markdown]
# El siguiente código conecta el mapa de la Región Metropolitana con la población por manzana del Censo 2017. Edite el código para que la figura tenga su nombre en el Titulo

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.colors as colors

#Crear figura y ejes
fig=plt.figure(figsize=(13,13))
ax=fig.add_subplot(111)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)

# cantidad de personas por manzana
manz = manz[manz["NOM_COMUNA"] == "LO PRADO"]
Z=manz['TOTAL_PERS']
manz.plot(ax=ax, column='TOTAL_PERS', cmap='Greens', legend=True, vmin=0, vmax=1000)

com_projected = com.to_crs(epsg=3857)
com_projected.boundary.plot(ax=ax, lw=0.2, color='k')
c = [-33.445, -70.72]
range_x = 0.03
range_y = 0.015
xlim= [c[1] - range_x, c[1] + range_x]
ylim= [c[0] - range_y, c[0] + range_y]
#xlim=[-70.8,-70.5]
#ylim=[-33.5,-33.4]
for x, y, label in zip(com_projected.geometry.centroid.x, com_projected.geometry.centroid.y, com_projected.NOM_COMUNA):
    if xlim[0]<x<xlim[1] and ylim[0]<y<ylim[1]:
        ax.text(x, y, label, fontsize = 10)
        
ax.set_xlim(xlim)
ax.set_ylim(ylim);

## Reemplace 'XXX' por su apellido
ax.set_title('RM - Población total por manzana Comuna de Lo Prado, Santiago - Censo 2017 - Ejecutado por Hernandez',fontsize=10)

## Reemplace 'XXX' por su apellido en el nombre del archivo de salida 
fig.savefig('PoblacionRM_C2017_Hernandez.jpg')

# %% [markdown]
# ## 5. Cierre de la Actividad 01: Repositorio presonal
#
# Para terminar la Actividad 01, deben hacer los siguientes pasos:
# - Crear un repositorio en su cuenta personal con el nombre ``IMT2200-<NOMBRE>-<APELLIDO>`` y clonar en su computador.
# - Crear una carpeta adentro llamada "Actividad 01" y copiar adentro el contenido de la carpeta "Actividad 01" del repositorio del curso.
# - Actualizar el repositorio agregando el Notebook de Jupyter y la imagen con el Mapa con su nombre.
# - Editar el archivo ``README.md`` para describir su repositorio.
# - Entregar en el módulo ``Actividad 1`` en Canvas la URL de su repositorio para corrección.
